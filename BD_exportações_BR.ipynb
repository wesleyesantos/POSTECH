# %% [markdown]
# <a href="https://colab.research.google.com/github/wesleyesantos/POSTECH/blob/main/BD_exporta%C3%A7%C3%B5es_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
bd_export = pd.read_csv('/content/database_export_gov.csv', sep=';')

# %%
bd_export.dropna()
# Out:
#         CO_ANO  CO_MES      CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0         1997      11  74122000.0     10.0    249.0        SP     4.0
# 1         1997      11  73082000.0     10.0     97.0        MG     7.0
# 2         1997      11  84248119.0     11.0    196.0        SP     1.0
# 3         1997      11  48239090.0     10.0    586.0        MN     9.0
# 4         1997      11  72112910.0     10.0    850.0        SP     1.0
# ...        ...     ...         ...      ...      ...       ...     ...
# 942707    1998       1  85115010.0     11.0     63.0        ND     7.0
# 942708    1998       1  40119990.0     11.0    586.0        SP     7.0
# 942709    1998       1  56031290.0     10.0    586.0        PR     7.0
# 942710    1998       1  99997103.0     10.0    245.0        RJ     9.0
# 942711    1998       1   9011110.0     21.0     87.0        ES     1.0
#
#            CO_URF  QT_ESTAT  KG_LIQUIDO    VL_FOB
# 0        817600.0       0.0         0.0       3.0
# ...

# %%
bd_export = bd_export[bd_export['CO_NCM']<22049999]
bd_export = bd_export[bd_export['CO_NCM']>22040000]

# %%
bd_export = bd_export[bd_export['SG_UF_NCM'] == 'RS']

# %%
bd_export.groupby('CO_ANO').count()
# Out:
#         CO_MES  CO_NCM  CO_UNID  CO_PAIS  SG_UF_NCM  CO_VIA  CO_URF  QT_ESTAT  \
# CO_ANO
# 1997       134     134      134      134        134     134     134       134
# 1998        86      86       86       86         86      86      86        86
#
#         KG_LIQUIDO  VL_FOB
# CO_ANO
# 1997           134     134
# 1998            86      86
